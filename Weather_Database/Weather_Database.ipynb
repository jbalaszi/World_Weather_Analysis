# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrival      ")
print("-----------------------------")

# Create counters.
record_count = 1 
set_count = 1
# Out:
# Beginning Data Retrival
# -----------------------------

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=39e685c6310e15cb3c572dc93c3701ef

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=39e685c6310e15cb3c572dc93c3701ef&q=Boston

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrival      ")
print("-----------------------------")

# Create counters.
record_count = 1 
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50) :
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count +=1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
      
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrival
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | matara
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | angra
# City not found. Skipping...
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | tuatapere
# Processing Record 8 of Set 1 | timra
# Processing Record 9 of Set 1 | makakilo city
# Processing Record 10 of Set 1 | flinders
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | faanui
# Processing Record 13 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 1 | roebourne
# Processing Record 15 of Set 1 | antalaha
# Processing Record 16 of Set 1 | faya
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | shchelyayur
# City not found. Skipping...
# Processing Record 19 of Set 1 | asau
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | ancud
# Processing Record 22 of Set 1 | novo aripuana
# Processing Record 23 of Set 1 | stabat
# Processing Record 24 of Set 1 | chuy
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | jinchengjiang
# City not found. Skipping...
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | lompoc
# Processing Record 30 of Set 1 | goderich
# Processing Record 31 of Set 1 | general pico
# Processing Record 32 of Set 1 | saint-francois
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | port hedland
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | san juan
# Processing Record 38 of Set 1 | dondo
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | saskylakh
# Processing Record 41 of Set 1 | longyearbyen
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | klaksvik
# Processing Record 44 of Set 1 | bianzhuang
# Processing Record 45 of Set 1 | kaitangata
# Processing Record 46 of Set 1 | portland
# Processing Record 47 of Set 1 | hambantota
# Processing Record 48 of Set 1 | escarcega
# Processing Record 49 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 50 of Set 1 | sambava
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | prince rupert
# Processing Record 3 of Set 2 | egvekinot
# Processing Record 4 of Set 2 | adana
# Processing Record 5 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 2 | seoul
# Processing Record 7 of Set 2 | san pedro
# Processing Record 8 of Set 2 | igarka
# Processing Record 9 of Set 2 | lorengau
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | tasiilaq
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | omsukchan
# Processing Record 14 of Set 2 | taltal
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | alofi
# Processing Record 17 of Set 2 | tarko-sale
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | kollegal
# Processing Record 22 of Set 2 | hofn
# Processing Record 23 of Set 2 | ballitoville
# Processing Record 24 of Set 2 | buenos aires
# Processing Record 25 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 2 | bati
# Processing Record 27 of Set 2 | pevek
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | yatou
# Processing Record 30 of Set 2 | araouane
# Processing Record 31 of Set 2 | chokurdakh
# Processing Record 32 of Set 2 | korla
# Processing Record 33 of Set 2 | conakry
# Processing Record 34 of Set 2 | bengkulu
# Processing Record 35 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | kununurra
# Processing Record 38 of Set 2 | oshawa
# Processing Record 39 of Set 2 | namtsy
# Processing Record 40 of Set 2 | qasigiannguit
# Processing Record 41 of Set 2 | trairi
# Processing Record 42 of Set 2 | sayyan
# Processing Record 43 of Set 2 | markapur
# Processing Record 44 of Set 2 | lasa
# Processing Record 45 of Set 2 | saldanha
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | nikolskoye
# Processing Record 48 of Set 2 | hamilton
# Processing Record 49 of Set 2 | georgetown
# Processing Record 50 of Set 2 | marystown
# Processing Record 1 of Set 3 | new norfolk
# Processing Record 2 of Set 3 | teya
# Processing Record 3 of Set 3 | yulara
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 3 | bomet
# Processing Record 7 of Set 3 | geraldton
# Processing Record 8 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 3 | ayan
# Processing Record 10 of Set 3 | kongoussi
# Processing Record 11 of Set 3 | kruisfontein
# Processing Record 12 of Set 3 | whitehorse
# Processing Record 13 of Set 3 | olavarria
# Processing Record 14 of Set 3 | mogadishu
# Processing Record 15 of Set 3 | ekibastuz
# Processing Record 16 of Set 3 | fortuna
# Processing Record 17 of Set 3 | belousovka
# Processing Record 18 of Set 3 | mwinilunga
# Processing Record 19 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 3 | iqaluit
# Processing Record 21 of Set 3 | puerto ayora
# Processing Record 22 of Set 3 | esperance
# Processing Record 23 of Set 3 | katsuura
# Processing Record 24 of Set 3 | cidreira
# Processing Record 25 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 3 | toba
# Processing Record 27 of Set 3 | coihaique
# Processing Record 28 of Set 3 | tiksi
# Processing Record 29 of Set 3 | halifax
# Processing Record 30 of Set 3 | reno
# Processing Record 31 of Set 3 | itapirapua
# Processing Record 32 of Set 3 | sarkand
# Processing Record 33 of Set 3 | touros
# Processing Record 34 of Set 3 | kashi
# Processing Record 35 of Set 3 | kavieng
# Processing Record 36 of Set 3 | havelock
# Processing Record 37 of Set 3 | bayan
# Processing Record 38 of Set 3 | padang
# Processing Record 39 of Set 3 | port-cartier
# Processing Record 40 of Set 3 | paratinga
# Processing Record 41 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 3 | salalah
# Processing Record 44 of Set 3 | saint george
# Processing Record 45 of Set 3 | hobart
# Processing Record 46 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 3 | walvis bay
# Processing Record 48 of Set 3 | along
# Processing Record 49 of Set 3 | upernavik
# Processing Record 50 of Set 3 | davydivka
# Processing Record 1 of Set 4 | new plymouth
# Processing Record 2 of Set 4 | deer lake
# Processing Record 3 of Set 4 | vostok
# Processing Record 4 of Set 4 | kalmunai
# Processing Record 5 of Set 4 | san cristobal
# Processing Record 6 of Set 4 | daru
# Processing Record 7 of Set 4 | dekar
# Processing Record 8 of Set 4 | arraial do cabo
# Processing Record 9 of Set 4 | sisimiut
# Processing Record 10 of Set 4 | illapel
# Processing Record 11 of Set 4 | shakiso
# Processing Record 12 of Set 4 | quang ngai
# Processing Record 13 of Set 4 | oktyabrskoye
# Processing Record 14 of Set 4 | badaojiang
# City not found. Skipping...
# Processing Record 15 of Set 4 | axim
# Processing Record 16 of Set 4 | clyde river
# Processing Record 17 of Set 4 | eina
# Processing Record 18 of Set 4 | zeya
# Processing Record 19 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 4 | xai-xai
# Processing Record 21 of Set 4 | vrangel
# Processing Record 22 of Set 4 | torbay
# Processing Record 23 of Set 4 | carnarvon
# Processing Record 24 of Set 4 | xichang
# Processing Record 25 of Set 4 | victoria
# Processing Record 26 of Set 4 | jamestown
# Processing Record 27 of Set 4 | bonavista
# Processing Record 28 of Set 4 | barra dos coqueiros
# Processing Record 29 of Set 4 | cherskiy
# Processing Record 30 of Set 4 | busselton
# Processing Record 31 of Set 4 | juneau
# Processing Record 32 of Set 4 | nanakuli
# Processing Record 33 of Set 4 | luba
# Processing Record 34 of Set 4 | haines junction
# Processing Record 35 of Set 4 | north bend
# Processing Record 36 of Set 4 | twante
# Processing Record 37 of Set 4 | whitley bay
# Processing Record 38 of Set 4 | la orilla
# Processing Record 39 of Set 4 | pacific grove
# Processing Record 40 of Set 4 | mount isa
# Processing Record 41 of Set 4 | arcos de la frontera
# Processing Record 42 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 4 | leeton
# Processing Record 44 of Set 4 | puerto escondido
# Processing Record 45 of Set 4 | abdanan
# Processing Record 46 of Set 4 | broome
# Processing Record 47 of Set 4 | hovd
# Processing Record 48 of Set 4 | saint-philippe
# Processing Record 49 of Set 4 | broken hill
# Processing Record 50 of Set 4 | provideniya
# Processing Record 1 of Set 5 | pangkalanbuun
# Processing Record 2 of Set 5 | hongjiang
# Processing Record 3 of Set 5 | port hardy
# Processing Record 4 of Set 5 | leningradskiy
# Processing Record 5 of Set 5 | sabinas hidalgo
# Processing Record 6 of Set 5 | khash
# Processing Record 7 of Set 5 | isangel
# Processing Record 8 of Set 5 | aklavik
# Processing Record 9 of Set 5 | terracina
# Processing Record 10 of Set 5 | nusaybin
# Processing Record 11 of Set 5 | anaimalai
# Processing Record 12 of Set 5 | cockburn town
# Processing Record 13 of Set 5 | baherden
# Processing Record 14 of Set 5 | dryden
# Processing Record 15 of Set 5 | asuncion
# Processing Record 16 of Set 5 | pampas
# Processing Record 17 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 5 | batagay
# Processing Record 19 of Set 5 | otaki
# Processing Record 20 of Set 5 | ribeira grande
# Processing Record 21 of Set 5 | bosaso
# Processing Record 22 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 23 of Set 5 | port elizabeth
# Processing Record 24 of Set 5 | margate
# Processing Record 25 of Set 5 | sanchor
# Processing Record 26 of Set 5 | neuquen
# Processing Record 27 of Set 5 | half moon bay
# Processing Record 28 of Set 5 | cape town
# Processing Record 29 of Set 5 | laje
# Processing Record 30 of Set 5 | cabo san lucas
# Processing Record 31 of Set 5 | itarema
# Processing Record 32 of Set 5 | envira
# Processing Record 33 of Set 5 | sesheke
# Processing Record 34 of Set 5 | batesville
# Processing Record 35 of Set 5 | chincha alta
# Processing Record 36 of Set 5 | mariental
# Processing Record 37 of Set 5 | namibe
# Processing Record 38 of Set 5 | baruun-urt
# Processing Record 39 of Set 5 | dakar
# Processing Record 40 of Set 5 | krasnyy tekstilshchik
# City not found. Skipping...
# Processing Record 41 of Set 5 | ilulissat
# Processing Record 42 of Set 5 | thinadhoo
# Processing Record 43 of Set 5 | atuona
# Processing Record 44 of Set 5 | hasaki
# Processing Record 45 of Set 5 | urambo
# Processing Record 46 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 5 | blankenberge
# Processing Record 48 of Set 5 | dubbo
# Processing Record 49 of Set 5 | severo-kurilsk
# Processing Record 50 of Set 5 | carlos barbosa
# Processing Record 1 of Set 6 | ulaangom
# Processing Record 2 of Set 6 | kavaratti
# Processing Record 3 of Set 6 | cortez
# Processing Record 4 of Set 6 | camocim
# Processing Record 5 of Set 6 | campos
# Processing Record 6 of Set 6 | ambilobe
# Processing Record 7 of Set 6 | tual
# Processing Record 8 of Set 6 | ponta do sol
# Processing Record 9 of Set 6 | robe
# Processing Record 10 of Set 6 | sitka
# Processing Record 11 of Set 6 | revelstoke
# Processing Record 12 of Set 6 | tabou
# Processing Record 13 of Set 6 | rabo de peixe
# Processing Record 14 of Set 6 | luderitz
# Processing Record 15 of Set 6 | eyrarbakki
# Processing Record 16 of Set 6 | ruteng
# Processing Record 17 of Set 6 | najran
# Processing Record 18 of Set 6 | olafsvik
# Processing Record 19 of Set 6 | husavik
# Processing Record 20 of Set 6 | dunkwa
# Processing Record 21 of Set 6 | fort-shevchenko
# Processing Record 22 of Set 6 | majene
# Processing Record 23 of Set 6 | mataram
# Processing Record 24 of Set 6 | nakatunguru
# Processing Record 25 of Set 6 | pilar
# Processing Record 26 of Set 6 | rio grande
# Processing Record 27 of Set 6 | taoudenni
# Processing Record 28 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 6 | guerrero negro
# Processing Record 30 of Set 6 | castro
# Processing Record 31 of Set 6 | ust-tsilma
# Processing Record 32 of Set 6 | manggar
# Processing Record 33 of Set 6 | buraydah
# Processing Record 34 of Set 6 | livingston
# Processing Record 35 of Set 6 | dikson
# Processing Record 36 of Set 6 | norman wells
# Processing Record 37 of Set 6 | uige
# Processing Record 38 of Set 6 | dapaong
# Processing Record 39 of Set 6 | sakaiminato
# Processing Record 40 of Set 6 | druzhba
# Processing Record 41 of Set 6 | bilibino
# Processing Record 42 of Set 6 | zarubino
# Processing Record 43 of Set 6 | nanortalik
# Processing Record 44 of Set 6 | point pedro
# Processing Record 45 of Set 6 | guatire
# Processing Record 46 of Set 6 | adrar
# Processing Record 47 of Set 6 | tabas
# Processing Record 48 of Set 6 | alice springs
# Processing Record 49 of Set 6 | chara
# Processing Record 50 of Set 6 | cozumel
# Processing Record 1 of Set 7 | beringovskiy
# Processing Record 2 of Set 7 | marawi
# Processing Record 3 of Set 7 | chigorodo
# Processing Record 4 of Set 7 | vardo
# Processing Record 5 of Set 7 | havre-saint-pierre
# Processing Record 6 of Set 7 | numan
# Processing Record 7 of Set 7 | talnakh
# Processing Record 8 of Set 7 | lata
# Processing Record 9 of Set 7 | darhan
# Processing Record 10 of Set 7 | damietta
# Processing Record 11 of Set 7 | kjollefjord
# Processing Record 12 of Set 7 | minuri
# Processing Record 13 of Set 7 | kiunga
# Processing Record 14 of Set 7 | jiaocheng
# Processing Record 15 of Set 7 | mandurah
# Processing Record 16 of Set 7 | turayf
# Processing Record 17 of Set 7 | mehamn
# Processing Record 18 of Set 7 | malakal
# Processing Record 19 of Set 7 | vila franca do campo
# Processing Record 20 of Set 7 | la ronge
# Processing Record 21 of Set 7 | shache
# Processing Record 22 of Set 7 | christchurch
# Processing Record 23 of Set 7 | biak
# Processing Record 24 of Set 7 | ahipara
# Processing Record 25 of Set 7 | cravo norte
# Processing Record 26 of Set 7 | dhidhdhoo
# Processing Record 27 of Set 7 | viedma
# Processing Record 28 of Set 7 | amurzet
# Processing Record 29 of Set 7 | parakou
# Processing Record 30 of Set 7 | bethel
# Processing Record 31 of Set 7 | sangin
# Processing Record 32 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 33 of Set 7 | veraval
# Processing Record 34 of Set 7 | hithadhoo
# Processing Record 35 of Set 7 | opuwo
# Processing Record 36 of Set 7 | usinsk
# Processing Record 37 of Set 7 | moratuwa
# Processing Record 38 of Set 7 | zemio
# Processing Record 39 of Set 7 | tautira
# Processing Record 40 of Set 7 | beloha
# Processing Record 41 of Set 7 | airai
# Processing Record 42 of Set 7 | kamaishi
# Processing Record 43 of Set 7 | tsogni
# Processing Record 44 of Set 7 | funtua
# Processing Record 45 of Set 7 | moravita
# Processing Record 46 of Set 7 | ostrovnoy
# Processing Record 47 of Set 7 | san rafael
# Processing Record 48 of Set 7 | wadi maliz
# Processing Record 49 of Set 7 | muzhi
# Processing Record 50 of Set 7 | gravelbourg
# Processing Record 1 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 8 | san patricio
# Processing Record 3 of Set 8 | tuzha
# Processing Record 4 of Set 8 | rocha
# Processing Record 5 of Set 8 | bay roberts
# Processing Record 6 of Set 8 | nador
# Processing Record 7 of Set 8 | yumen
# Processing Record 8 of Set 8 | noumea
# Processing Record 9 of Set 8 | celestun
# Processing Record 10 of Set 8 | mayo
# Processing Record 11 of Set 8 | muroto
# Processing Record 12 of Set 8 | yara
# Processing Record 13 of Set 8 | zlobin
# Processing Record 14 of Set 8 | lumeje
# Processing Record 15 of Set 8 | los llanos de aridane
# Processing Record 16 of Set 8 | homer
# Processing Record 17 of Set 8 | khani
# Processing Record 18 of Set 8 | coos bay
# Processing Record 19 of Set 8 | sertania
# Processing Record 20 of Set 8 | ngunguru
# Processing Record 21 of Set 8 | souillac
# Processing Record 22 of Set 8 | donji vakuf
# Processing Record 23 of Set 8 | araceli
# Processing Record 24 of Set 8 | wattegama
# Processing Record 25 of Set 8 | kisarawe
# Processing Record 26 of Set 8 | vanavara
# Processing Record 27 of Set 8 | belyy yar
# Processing Record 28 of Set 8 | codrington
# Processing Record 29 of Set 8 | pando
# Processing Record 30 of Set 8 | waingapu
# Processing Record 31 of Set 8 | youkounkoun
# Processing Record 32 of Set 8 | abu dhabi
# Processing Record 33 of Set 8 | markivka
# Processing Record 34 of Set 8 | mimongo
# Processing Record 35 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 36 of Set 8 | flin flon
# Processing Record 37 of Set 8 | harper
# Processing Record 38 of Set 8 | tahe
# Processing Record 39 of Set 8 | mount gambier
# Processing Record 40 of Set 8 | strezhevoy
# Processing Record 41 of Set 8 | bouna
# Processing Record 42 of Set 8 | lavrentiya
# Processing Record 43 of Set 8 | angouleme
# Processing Record 44 of Set 8 | canton
# Processing Record 45 of Set 8 | bambanglipuro
# Processing Record 46 of Set 8 | wanning
# Processing Record 47 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 48 of Set 8 | brae
# Processing Record 49 of Set 8 | darya khan
# Processing Record 50 of Set 8 | channel-port aux basques
# Processing Record 1 of Set 9 | safaga
# Processing Record 2 of Set 9 | lebu
# Processing Record 3 of Set 9 | asfi
# Processing Record 4 of Set 9 | pandan niog
# Processing Record 5 of Set 9 | port blair
# Processing Record 6 of Set 9 | semey
# Processing Record 7 of Set 9 | vestmannaeyjar
# Processing Record 8 of Set 9 | skibbereen
# Processing Record 9 of Set 9 | kawalu
# Processing Record 10 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 9 | mweka
# Processing Record 12 of Set 9 | constitucion
# Processing Record 13 of Set 9 | uzhur
# Processing Record 14 of Set 9 | rumford
# Processing Record 15 of Set 9 | campbell river
# Processing Record 16 of Set 9 | bandarbeyla
# Processing Record 17 of Set 9 | lagoa
# Processing Record 18 of Set 9 | salinas
# Processing Record 19 of Set 9 | toamasina
# Processing Record 20 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 9 | narrabri
# Processing Record 22 of Set 9 | bathsheba
# Processing Record 23 of Set 9 | fortuna foothills
# Processing Record 24 of Set 9 | bahia blanca
# Processing Record 25 of Set 9 | arawa
# Processing Record 26 of Set 9 | kota
# Processing Record 27 of Set 9 | rio de janeiro
# Processing Record 28 of Set 9 | hermon
# Processing Record 29 of Set 9 | acarau
# Processing Record 30 of Set 9 | takoradi
# Processing Record 31 of Set 9 | ushtobe
# Processing Record 32 of Set 9 | nakamura
# Processing Record 33 of Set 9 | ixcaquixtla
# City not found. Skipping...
# Processing Record 34 of Set 9 | mayumba
# Processing Record 35 of Set 9 | tezu
# Processing Record 36 of Set 9 | caribou
# Processing Record 37 of Set 9 | virginia beach
# Processing Record 38 of Set 9 | cordoba
# Processing Record 39 of Set 9 | colares
# Processing Record 40 of Set 9 | namatanai
# Processing Record 41 of Set 9 | lufilufi
# Processing Record 42 of Set 9 | kortkeros
# Processing Record 43 of Set 9 | ewa beach
# Processing Record 44 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 45 of Set 9 | san andres
# Processing Record 46 of Set 9 | sidi ali
# Processing Record 47 of Set 9 | dingle
# Processing Record 48 of Set 9 | hobyo
# Processing Record 49 of Set 9 | cuenca
# Processing Record 50 of Set 9 | santa cruz
# Processing Record 1 of Set 10 | guarda
# Processing Record 2 of Set 10 | rio claro
# Processing Record 3 of Set 10 | moron
# Processing Record 4 of Set 10 | bikin
# Processing Record 5 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 10 | iranduba
# Processing Record 7 of Set 10 | barddhaman
# Processing Record 8 of Set 10 | sao filipe
# Processing Record 9 of Set 10 | correntina
# Processing Record 10 of Set 10 | douglas
# Processing Record 11 of Set 10 | williston
# Processing Record 12 of Set 10 | auki
# Processing Record 13 of Set 10 | pundaguitan
# Processing Record 14 of Set 10 | thunder bay
# Processing Record 15 of Set 10 | mpanda
# Processing Record 16 of Set 10 | quatre cocos
# Processing Record 17 of Set 10 | nemuro
# Processing Record 18 of Set 10 | kirakira
# Processing Record 19 of Set 10 | hay river
# Processing Record 20 of Set 10 | kamyaran
# Processing Record 21 of Set 10 | pallisa
# Processing Record 22 of Set 10 | hanyang
# Processing Record 23 of Set 10 | uyemskiy
# Processing Record 24 of Set 10 | podosinovets
# Processing Record 25 of Set 10 | alberton
# Processing Record 26 of Set 10 | deputatskiy
# Processing Record 27 of Set 10 | muisne
# Processing Record 28 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 10 | inirida
# Processing Record 30 of Set 10 | northam
# Processing Record 31 of Set 10 | benjamin hill
# Processing Record 32 of Set 10 | ouidah
# Processing Record 33 of Set 10 | shingu
# Processing Record 34 of Set 10 | melo
# Processing Record 35 of Set 10 | manado
# Processing Record 36 of Set 10 | cervo
# Processing Record 37 of Set 10 | teguldet
# Processing Record 38 of Set 10 | kenora
# Processing Record 39 of Set 10 | jati
# Processing Record 40 of Set 10 | guymon
# Processing Record 41 of Set 10 | corn island
# Processing Record 42 of Set 10 | kneza
# City not found. Skipping...
# Processing Record 43 of Set 10 | narsaq
# Processing Record 44 of Set 10 | owando
# Processing Record 45 of Set 10 | balma
# Processing Record 46 of Set 10 | jvari
# Processing Record 47 of Set 10 | carmen
# Processing Record 48 of Set 10 | frunzivka
# Processing Record 49 of Set 10 | komsomolskiy
# Processing Record 50 of Set 10 | xinqing
# Processing Record 1 of Set 11 | ellisras
# Processing Record 2 of Set 11 | shestakovo
# Processing Record 3 of Set 11 | ndjole
# Processing Record 4 of Set 11 | ler
# Processing Record 5 of Set 11 | ranong
# Processing Record 6 of Set 11 | pachora
# Processing Record 7 of Set 11 | borborema
# Processing Record 8 of Set 11 | te anau
# Processing Record 9 of Set 11 | pozo colorado
# Processing Record 10 of Set 11 | mbuji-mayi
# Processing Record 11 of Set 11 | busayra
# Processing Record 12 of Set 11 | sobolevo
# Processing Record 13 of Set 11 | praya
# Processing Record 14 of Set 11 | tyukalinsk
# Processing Record 15 of Set 11 | tigil
# Processing Record 16 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 11 | pisco
# Processing Record 18 of Set 11 | ozernovskiy
# Processing Record 19 of Set 11 | alcudia
# Processing Record 20 of Set 11 | gat
# Processing Record 21 of Set 11 | novo oriente
# Processing Record 22 of Set 11 | karpogory
# Processing Record 23 of Set 11 | porbandar
# Processing Record 24 of Set 11 | pailon
# Processing Record 25 of Set 11 | sabang
# Processing Record 26 of Set 11 | grafton
# Processing Record 27 of Set 11 | bucerias
# Processing Record 28 of Set 11 | price
# Processing Record 29 of Set 11 | sept-iles
# Processing Record 30 of Set 11 | okhotsk
# Processing Record 31 of Set 11 | porkhov
# Processing Record 32 of Set 11 | benghazi
# Processing Record 33 of Set 11 | lere
# Processing Record 34 of Set 11 | vao
# Processing Record 35 of Set 11 | smithers
# Processing Record 36 of Set 11 | kudahuvadhoo
# Processing Record 37 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 11 | lamu
# Processing Record 39 of Set 11 | maine-soroa
# Processing Record 40 of Set 11 | bonthe
# Processing Record 41 of Set 11 | saint-augustin
# Processing Record 42 of Set 11 | college
# Processing Record 43 of Set 11 | changji
# Processing Record 44 of Set 11 | churapcha
# Processing Record 45 of Set 11 | saint-joseph
# Processing Record 46 of Set 11 | mirnyy
# Processing Record 47 of Set 11 | horsham
# Processing Record 48 of Set 11 | tallahassee
# Processing Record 49 of Set 11 | kantunilkin
# Processing Record 50 of Set 11 | myrtle beach
# Processing Record 1 of Set 12 | maarianhamina
# Processing Record 2 of Set 12 | gorontalo
# Processing Record 3 of Set 12 | lyubeshiv
# City not found. Skipping...
# Processing Record 4 of Set 12 | sikasso
# Processing Record 5 of Set 12 | lusambo
# Processing Record 6 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 12 | tiarei
# Processing Record 8 of Set 12 | tura
# Processing Record 9 of Set 12 | port-gentil
# Processing Record 10 of Set 12 | haubourdin
# Processing Record 11 of Set 12 | yazykovo
# Processing Record 12 of Set 12 | oistins
# Processing Record 13 of Set 12 | kalemie
# Processing Record 14 of Set 12 | zhigansk
# Processing Record 15 of Set 12 | pangoa
# Processing Record 16 of Set 12 | jacqueville
# Processing Record 17 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 12 | san carlos de bariloche
# Processing Record 19 of Set 12 | sagpon
# Processing Record 20 of Set 12 | san luis
# Processing Record 21 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 12 | leshukonskoye
# Processing Record 23 of Set 12 | troitsko-pechorsk
# Processing Record 24 of Set 12 | talara
# Processing Record 25 of Set 12 | kushiro
# Processing Record 26 of Set 12 | bima
# Processing Record 27 of Set 12 | malindi
# Processing Record 28 of Set 12 | paucartambo
# City not found. Skipping...
# Processing Record 29 of Set 12 | barrow
# Processing Record 30 of Set 12 | san quintin
# Processing Record 31 of Set 12 | berlevag
# Processing Record 32 of Set 12 | pecos
# Processing Record 33 of Set 12 | mulege
# Processing Record 34 of Set 12 | balkhash
# Processing Record 35 of Set 12 | naze
# Processing Record 36 of Set 12 | takab
# Processing Record 37 of Set 12 | vila velha
# Processing Record 38 of Set 12 | bucak
# Processing Record 39 of Set 12 | nigde
# Processing Record 40 of Set 12 | mecca
# Processing Record 41 of Set 12 | abadiania
# Processing Record 42 of Set 12 | fayaoue
# Processing Record 43 of Set 12 | porto recanati
# Processing Record 44 of Set 12 | okato
# Processing Record 45 of Set 12 | upata
# Processing Record 46 of Set 12 | pinega
# Processing Record 47 of Set 12 | bolivar
# Processing Record 48 of Set 12 | marfino
# Processing Record 49 of Set 12 | ixtapa
# Processing Record 50 of Set 12 | sultanpur
# Processing Record 1 of Set 13 | gallipoli
# Processing Record 2 of Set 13 | kutum
# Processing Record 3 of Set 13 | praia da vitoria
# Processing Record 4 of Set 13 | canto do buriti
# Processing Record 5 of Set 13 | moose factory
# Processing Record 6 of Set 13 | batemans bay
# Processing Record 7 of Set 13 | beira
# Processing Record 8 of Set 13 | pokhara
# Processing Record 9 of Set 13 | bonnyville
# Processing Record 10 of Set 13 | rupert
# Processing Record 11 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 12 of Set 13 | finschhafen
# Processing Record 13 of Set 13 | male
# Processing Record 14 of Set 13 | jiroft
# City not found. Skipping...
# Processing Record 15 of Set 13 | mandalgovi
# Processing Record 16 of Set 13 | lake charles
# Processing Record 17 of Set 13 | chanthaburi
# Processing Record 18 of Set 13 | dukat
# Processing Record 19 of Set 13 | solsvik
# City not found. Skipping...
# Processing Record 20 of Set 13 | finote selam
# Processing Record 21 of Set 13 | kysyl-syr
# Processing Record 22 of Set 13 | bloomingdale
# Processing Record 23 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 24 of Set 13 | felanitx
# Processing Record 25 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 13 | jalu
# Processing Record 27 of Set 13 | dicabisagan
# Processing Record 28 of Set 13 | nizwa
# Processing Record 29 of Set 13 | palmer
# Processing Record 30 of Set 13 | palma di montechiaro
# Processing Record 31 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 32 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 33 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 34 of Set 13 | urubicha
# Processing Record 35 of Set 13 | moree
# Processing Record 36 of Set 13 | tommot
# Processing Record 37 of Set 13 | mallaig
# Processing Record 38 of Set 13 | madera
# Processing Record 39 of Set 13 | ugoofaaru
# Processing Record 40 of Set 13 | tutubigan
# Processing Record 41 of Set 13 | yelkhovka
# Processing Record 42 of Set 13 | general roca
# Processing Record 43 of Set 13 | ous
# Processing Record 44 of Set 13 | caninde de sao francisco
# Processing Record 45 of Set 13 | rawson
# Processing Record 46 of Set 13 | noshiro
# Processing Record 47 of Set 13 | oriximina
# Processing Record 48 of Set 13 | bud
# Processing Record 49 of Set 13 | goundam
# Processing Record 50 of Set 13 | baie-comeau
# Processing Record 1 of Set 14 | zabol
# Processing Record 2 of Set 14 | gayny
# Processing Record 3 of Set 14 | puksoozero
# Processing Record 4 of Set 14 | sao jose da coroa grande
# Processing Record 5 of Set 14 | indramayu
# Processing Record 6 of Set 14 | grindavik
# Processing Record 7 of Set 14 | the valley
# Processing Record 8 of Set 14 | kandrian
# Processing Record 9 of Set 14 | cayenne
# Processing Record 10 of Set 14 | bambous virieux
# Processing Record 11 of Set 14 | itoman
# Processing Record 12 of Set 14 | sakakah
# Processing Record 13 of Set 14 | belchertown
# Processing Record 14 of Set 14 | mingaora
# Processing Record 15 of Set 14 | zhangye
# Processing Record 16 of Set 14 | iralaya
# Processing Record 17 of Set 14 | genhe
# Processing Record 18 of Set 14 | keith
# Processing Record 19 of Set 14 | mizdah
# Processing Record 20 of Set 14 | kankan
# Processing Record 21 of Set 14 | sechura
# Processing Record 22 of Set 14 | samarai
# Processing Record 23 of Set 14 | seidu
# Processing Record 24 of Set 14 | hami
# Processing Record 25 of Set 14 | maralal
# Processing Record 26 of Set 14 | emerald
# Processing Record 27 of Set 14 | porto walter
# Processing Record 28 of Set 14 | salinopolis
# Processing Record 29 of Set 14 | tuban
# Processing Record 30 of Set 14 | havelian
# Processing Record 31 of Set 14 | banda aceh
# Processing Record 32 of Set 14 | vanderhoof
# Processing Record 33 of Set 14 | muros
# Processing Record 34 of Set 14 | urazovka
# Processing Record 35 of Set 14 | arman
# Processing Record 36 of Set 14 | booue
# Processing Record 37 of Set 14 | singaraja
# Processing Record 38 of Set 14 | sur
# Processing Record 39 of Set 14 | shelburne
# Processing Record 40 of Set 14 | klerksdorp
# Processing Record 41 of Set 14 | basi
# Processing Record 42 of Set 14 | vesoul
# Processing Record 43 of Set 14 | gimli
# Processing Record 44 of Set 14 | iwanai
# Processing Record 45 of Set 14 | fare
# Processing Record 46 of Set 14 | porto velho
# Processing Record 47 of Set 14 | mezen
# Processing Record 48 of Set 14 | adolfo lopez mateos
# Processing Record 49 of Set 14 | lourdes
# Processing Record 50 of Set 14 | encruzilhada do sul
# Processing Record 1 of Set 15 | eenhana
# Processing Record 2 of Set 15 | niksic
# Processing Record 3 of Set 15 | nizhniy tsasuchey
# Processing Record 4 of Set 15 | onega
# Processing Record 5 of Set 15 | dois vizinhos
# Processing Record 6 of Set 15 | nizhniy kuranakh
# Processing Record 7 of Set 15 | hvammstangi
# City not found. Skipping...
# Processing Record 8 of Set 15 | camopi
# Processing Record 9 of Set 15 | aripuana
# Processing Record 10 of Set 15 | caravelas
# Processing Record 11 of Set 15 | midland
# Processing Record 12 of Set 15 | labuan
# Processing Record 13 of Set 15 | gouyave
# Processing Record 14 of Set 15 | sinnamary
# Processing Record 15 of Set 15 | sibolga
# Processing Record 16 of Set 15 | kochki
# Processing Record 17 of Set 15 | keshorai patan
# Processing Record 18 of Set 15 | okha
# Processing Record 19 of Set 15 | storm lake
# Processing Record 20 of Set 15 | kathu
# Processing Record 21 of Set 15 | plettenberg bay
# Processing Record 22 of Set 15 | orlik
# Processing Record 23 of Set 15 | weihe
# Processing Record 24 of Set 15 | banon
# Processing Record 25 of Set 15 | szigetvar
# Processing Record 26 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 27 of Set 15 | wanaka
# Processing Record 28 of Set 15 | dubti
# Processing Record 29 of Set 15 | belaya gora
# Processing Record 30 of Set 15 | danjiangkou
# Processing Record 31 of Set 15 | kizner
# Processing Record 32 of Set 15 | omutinskoye
# City not found. Skipping...
# Processing Record 33 of Set 15 | ogaminana
# Processing Record 34 of Set 15 | sawtell
# Processing Record 35 of Set 15 | chapais
# Processing Record 36 of Set 15 | bratsk
# Processing Record 37 of Set 15 | olinda
# Processing Record 38 of Set 15 | waipawa
# Processing Record 39 of Set 15 | vila do maio
# Processing Record 40 of Set 15 | port augusta
# Processing Record 41 of Set 15 | zherdevka
# Processing Record 42 of Set 15 | porto novo
# Processing Record 43 of Set 15 | buala
# Processing Record 44 of Set 15 | henties bay
# Processing Record 45 of Set 15 | terra santa
# Processing Record 46 of Set 15 | shimoda
# Processing Record 47 of Set 15 | zhanaozen
# Processing Record 48 of Set 15 | salem
# Processing Record 49 of Set 15 | novyy urgal
# Processing Record 50 of Set 15 | santa flavia
# Processing Record 1 of Set 16 | formosa
# Processing Record 2 of Set 16 | zlotow
# Processing Record 3 of Set 16 | bloomfield
# Processing Record 4 of Set 16 | ruidoso
# Processing Record 5 of Set 16 | kapchorwa
# Processing Record 6 of Set 16 | vryheid
# Processing Record 7 of Set 16 | jinchang
# Processing Record 8 of Set 16 | gasa
# Processing Record 9 of Set 16 | neyshabur
# Processing Record 10 of Set 16 | sioux lookout
# Processing Record 11 of Set 16 | maghama
# City not found. Skipping...
# Processing Record 12 of Set 16 | pumiao
# Processing Record 13 of Set 16 | margahovit
# Processing Record 14 of Set 16 | naples
# Processing Record 15 of Set 16 | kamyshin
# Processing Record 16 of Set 16 | westport
# Processing Record 17 of Set 16 | cabarroguis
# Processing Record 18 of Set 16 | omboue
# Processing Record 19 of Set 16 | bardiyah
# Processing Record 20 of Set 16 | simao
# Processing Record 21 of Set 16 | fort nelson
# Processing Record 22 of Set 16 | brigantine
# Processing Record 23 of Set 16 | praia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas      CL -53.1500  -70.9167     57.00        54          90
# 1         Matara      LK   5.9485   80.5353     72.73        90          83
# 2        Ushuaia      AR -54.8000  -68.3000     57.20        51          75
# 3       Khatanga      RU  71.9667  102.5000    -26.25        86          98
# 4         Kodiak      US  57.7900 -152.4072     35.60        75          75
# 5      Tuatapere      NZ -46.1333  167.6833     72.00        51          72
# 6          Timra      SE  62.4870   17.3257     25.00        74           0
# 7  Makakilo City      US  21.3469 -158.0858     80.60        54           1
# 8       Flinders      AU -34.5833  150.8552     66.99        96         100
# 9        Rikitea      PF -23.1203 -134.9692     80.53        72          26
#
#    Wind Speed Weather Description
# 0       11.50     overcast clouds
# 1        2.42       broken clouds
# 2        9.22       broken clouds
# 3        7.99     overcast clouds
# 4       12.66          light snow
# 5        3.00       broken clouds
# 6       11.50           clear sky
# 7        9.22           clear sky
# 8        1.01     overcast clouds
# 9       10.11    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
